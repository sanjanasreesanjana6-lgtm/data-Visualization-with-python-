# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanasreesanjana6-lgtm/data-Visualization-with-python-/blob/main/ML_def_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DATA SET**::data set is a particular instance of data used to analysis and model buliding
#
# -->> data sets can be in any format like numerical data,image data ,categorical data,vedio data and voice data
#
# -->> the most popular data set is data set using the numerical data that is typically stored in a comma seperated values(csv)

# %% [markdown]
# **DATA WRANGLING**::it is process of converting the raw data to a user understandable
#
# -->>it includes several processes like data cleaning,data structuring,data importing,handling the missing data

# %% [markdown]
# **DATA VISUALIZATIONS**::process of converting the data into visual's
#
# -->> data visualizations include all the kind of garphs 15
#
# -->>data visualizations is also used in the machine learning for data processing and analysis

# %% [markdown]
# **OUTLIERS**::an outlier is a data point that is very different from the other data points
#
# -->>outliers are common and  expected in large data sets
#
# -->>box plot is used to detect this outliers
#
# -->>advance method of dealing with outliers include RANSAC method

# %% [markdown]
# **DATA IMPUTATION**::while transporting the data we may losse the some data which would be valuable
#
# -->> this data imputation is used to fill the missing values
#
# -->> interpolation techniques are used ,mostly used interpolation technique is **mean imputation**it replaces the missing with the mean value of entire feature columns

# %% [markdown]
# **DATA SCALING**:: means reducing the size of unused data/un important data
#
# -->>it will not delete the data but minimises ,due to this the product will work effectively

# %% [markdown]
# **DATA PARTITIONING**::in machine learning ,the machine learning is often partitioned training and testing set's
#
# -->>the model is trained in the trained set ,and tested in the testing set
#
# #this is the syntax used for data partition
#
# -->>#import
#
# from sklearn.model_selection import
#
# train_test_split
#
# X_train,X_test,y_train,y_test=train_test_split
#
# (X,y,test_size=0.3)

# %% [markdown]
# **SUPERVISED LEARNING**this is the core concept in machine learning that perform learning by studying the relationship between feature variables and target 🎯 variables (every input will have a valid output)
#
# a) continous target 🎯 varibles::
#
# linear regression, kneighbors regression(knr),support vector regression(svr)
#
# b) discreate target 🎯 variables::
#
# logistic regression classifier,support vector machine(svm),decision tree classifier

# %% [markdown]
# **UNSUPERVISED LEARNING**::unsupervised learning means we give input but we dont know the output right

# %% [markdown]
# **RENIFORCEMENT LEARNING (rl)** ::is atype of machine learning technique that enables an agent to learn in an interactive environment by trial and error using feedbacks from its own actions and experiences
#
#
# -->>reinforcement learning uses rewards and punishments as signals for positive and negative behavior

# %% [markdown]
# **CROSS VALIDATION**::means testing multiple times
#
# -->>the data is divided into k poritions each of them are tested k numder of times
#
# -->>by doing this we can avoid the error ocurring problems

# %% [markdown]
# **BIAS - VARIENCE TRADEOFF**::A model with high bias is too simple. It doesn’t learn enough from the data and makes lots of mistakes.
#
# A model with high variance is too complex. It learns too much from the training data—even the noise—and doesn’t work well on new data.
#
# Bias is how far your arrows are from the bullseye on average.
#
# If you always miss in the same way (like always too far left), you have high bias.
#
# Variance is how spread out your arrows are.
#
# If your arrows land all over the place—even if some hit the bullseye—you have high variance.

# %% [markdown]
# **PRINCIPLE COMPONENT ANALYSIS (pca)**::this is used to improve the features in the project
#
# -->>this is the advanced version of the ml

# %% [markdown]
# **EVOLUATION METRICS**::is used to make good predictions
#
# -->>can be evoluated using metrics such as accuracy,precision,recall,f1 score,and area under ROC curve(AUC)

# %% [markdown]
# **MATH CONCEPT**::The branch of math that deals with numbers and basic operations like addition, subtraction, multiplication, and division.
