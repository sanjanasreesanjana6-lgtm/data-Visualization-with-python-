# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanasreesanjana6-lgtm/data-Visualization-with-python-/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#addition
3+5+8
# Out:
# 16

# %%
a=4
b=5
if a<b:
    print("b is greater")
else:
    print("none")
# Out:
# b is greater

# %%
#sudtraction
print(5-4)
# Out:
# 1

# %%
#multipication
3*4
# Out:
# 0.5

# %%
#division
# gives the float as a float
4/2
# Out:
# 2.0

# %%
#floor division
#floating num is not allowed,returns only integer
56//5
# Out:
# 11

# %%
#exponent (power)
2**5
# Out:
# 32

# %%
2**3
# Out:
# 8

# %%
#modulus
#modulus means remainder
2%5
# Out:
# 2

# %%
4%7
# Out:
# 4

# %%
1%2
# Out:
# 1

# %%
4%2
# Out:
# 0

# %% [markdown]
# bodmas=brakects,order(power's),division,mulitiplication,addition,sudtraction
#
# **but in python we have pemdas rule = parantisis,exponential,multiplication,division,addtion,sudtraction**

# %%
2+2*4-5
# Out:
# 5

# %%
2**4+(1+1)*2-5
# Out:
# 15

# %% [markdown]
# 2**4+2*2-5
#
# 16+2*2-5
#
# 16+4-5
#
# 20-5
#
# 15

# %%
#notation for representing the large numbers
4E5
#this works as 4*10^5
# Out:
# 400000.0

# %%
3E9
# Out:
# 3000000000.0

# %% [markdown]
# the conditional operators are
#
# <,>,=,==,<=,>=
#
# these are mostly used in boolean (true or flase)
