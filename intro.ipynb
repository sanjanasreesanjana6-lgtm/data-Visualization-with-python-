# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanasreesanjana6-lgtm/data-Visualization-with-python-/blob/main/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#python is a case sensitive language and interpreter language(executes the code line by line)

a=345
print(a)

b="my name is "
#print(b)
type(b)

b=('6+7i')
print(b)
type(b)

print(b)
print(a)


y=8+8j

type(y)

x=True
type(x)

c=False
type(c)

#converting or typecasting
#used for changing the datatype to another
#we can convert the int to float ,float to int but we can't convert
#the complex to int or float ,because it is the combination of real and imaginary part ,so it will throw an error
x=complex(98.56)
x

l=float(90)
l

x=int(90.89889)
x

char='i'
type(char)

num=-898
float:90.87
print(type(num))
print(type(float))


a=float(89)
a

h=str(76)
h

x=str(87)
j=int("89")

x,j

# import random is used to pickup the random numbers
#it pick's up the numbers less than one to the last number
#for every time we run the code it pick's a random number
import random
print(random.randrange(90,980))

import random
print(random.randrange(1,90))

#this is used to select the random datatype's which we give
import random
num1= (random.random())
num1

import random
float=(random.random())
float

import random
int=(random.random())
int

#u can observe \n their which represents the new line
a=''' i have started learning the python
i hope to complete this
as soon as possible'''
a

my_string_variable = (''' i have started learning the python
 i hope to complete this ..
 as soon as possible ''')


#boolean
a=(5>9)
a


b=(5<9)
b

a=5
b=8
if a<b:
    print("b is greater")
else:
    print("a is greater")



print(5==6)
